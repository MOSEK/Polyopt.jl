# %% [markdown]
# # The standard pooling problem

# %% [markdown]
# * A pooling problem is a directed network flow problem
# * Three types of nodes:  <i>sources</i>, <i>pools</i> and <i>terminals</i>.
# * Commodities flow from sources to terminals, and commodities can be blended in intermediate pools.
# * Capacities for all nodes.
# * Different commodities have different quality parameters, and the terminals have quality requirements.
# * The pools control the quality at terminals by a <i>blending process</i>.
# * A nonlinear flow problem, NP hard in general.

# %% [markdown]
# We store the network in a structure, where <code>cost</code> is an adjacency matrix storing the cost for each edge in the network, we also store the quality parameters (or requirements) in <code>q</code> and the capacities in <code>cap</code>,

# %%
immutable PoolingNetwork
    ns   :: Int
    np   :: Int
    nt   :: Int
    cost :: SparseMatrixCSC{Float64,Int}
    q    :: Vector{Float64}
    cap  :: Vector{Float64}     
end

# %% [markdown]
# The following block of code is not important, it just plots a pooling network.

# %%
using Compose

immutable Node
    x :: Float64
    y :: Float64    
    radius :: Float64
    label :: ASCIIString
    text  :: ASCIIString
end

draw_node(n::Node) = compose(context(), ( compose(context(), circle(n.x, n.y, n.radius)),
    compose(context(), text(n.x, n.y, n.label, hcenter, vcenter)),
    compose(context(), text(n.x, n.y - (2*n.radius), n.text, hcenter, vbottom)) ))    

function draw_edge(a::Node, b::Node, label::ASCIIString)
    p = [b.x-a.x, b.y-a.y] ./ norm([b.x-a.x, b.y-a.y])
    compose(context(), 
        (compose(context(), line([(a.x+p[1]*a.radius, a.y+p[2]*a.radius), (b.x-p[1]*b.radius, b.y-p[2]*b.radius)])),
         compose(context(), text(a.x+(b.x-a.x)/2, a.y+(b.y-a.y)/2+0.02, label, hcenter, vtop))) )
end

function draw_network(G::PoolingNetwork)
    dx, dy = 0.4, 1.0/G.ns 
    
    N = [ [ Node(0.1,     dy*(i-0.5),.05,string(i),string("q<sub>",i,"</sub>")) for i=1:G.ns ];
          [ Node(0.1+dx,  dy*(i-0.5),.05,string(i+G.ns),string("w<sub>",i+G.ns,"</sub>")) for i=1:G.np ];
          [ Node(0.1+2*dx,dy*(i-0.5),.05,string(i+G.ns+G.np),string("q<sub>",i+G.ns+G.np,"</sub>")) for i=1:G.nt ] ]
    
    p = [draw_node(ni) for ni=N]
    for j=1:G.ns+G.np+G.nt
        for i=find(G.cost[:,j])
            push!(p, draw_edge(N[i], N[j], string("x<sub>",i,j,"</sub>"))) 
        end             
    end    
    compose(context(), fill(nothing), stroke("black"), p)
end
# Out:
# draw_network (generic function with 1 method)

# %% [markdown]
# One standard pooling test instance is the <i>Haverly</i> model,

# %%
N = PoolingNetwork(3, 1, 2, 
                   sparse([1,2,3,3,4,4],[4,4,5,6,5,6],[6,16,1,5,-9,-15],6,6), 
                   [3,1,2,0,2.5,1.5], 
                   [1,1,1,1,1/3,2/3] );

# %% [markdown]
# with quality parameters

# %%
N.q
# Out:
# 6-element Array{Float64,1}:
#  3.0
#  1.0
#  2.0
#  0.0
#  2.5
#  1.5

# %% [markdown]
# capacities,

# %%
N.cap
# Out:
# 6-element Array{Float64,1}:
#  1.0
#  1.0
#  1.0
#  1.0
#  0.333333
#  0.666667

# %% [markdown]
# and costs

# %%
N.cost
# Out:
# 6x6 sparse matrix with 6 Float64 entries:
# 	[1, 4]  =  6.0
# 	[2, 4]  =  16.0
# 	[3, 5]  =  1.0
# 	[4, 5]  =  -9.0
# 	[3, 6]  =  5.0
# 	[4, 6]  =  -15.0

# %% [markdown]
# Edges to terminals have a negative cost, corresponding to an income when a commodity is delivered.

# %%
draw_network(N)
# Out:
# Compose.Context(Compose.BoundingBox(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),1.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,1.0)),Compose.UnitBox{Void,Void,Void,Void}(nothing,nothing,nothing,nothing,Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Rotation{Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}}(0.0,Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.5,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.5))),nothing,Compose.ListNode{Compose.ComposeNode}(Compose.Context(Compose.BoundingBox(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),1.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,1.0)),Compose.UnitBox{Void,Void,Void,Void}(nothing,nothing,nothing,nothing,Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0)),Compose.Rotation{Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}}(0.0,Compose.Point{Compose.Measure{Compose.MeasureNil,Compose.MeasureNil},Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}}(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.5,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.5))),nothing,Compose.ListNode{Compose.ComposeNode}(Compose.Context(Compose.BoundingBox(Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),1.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,1.0)),Compose.UnitBox{Void,Void,Void,Void}(nothing,nothing,nothing,nothing,Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.MeasureNil(),Compose.MeasureNil(),0.0,0.0),Compose.Measure{Compose.MeasureNil,Compose.MeasureNil}(0.0,Compose.Mea ...

# %% [markdown]
# ## Setting up the problem

# %%
using Polyopt

# %%
x14, x24, x35, x36, x45, x46, w4 = variables(["x14"; "x24"; "x35"; "x36"; "x45"; "x46"; "w4"]);

# %% [markdown]
# In the <i>minimium cost</i> formulation we minimize $\sum_{(i,j)\in N} c_{i,j}x_{i,j}$.

# %%
obj = N.cost[1,4]*x14 + N.cost[2,4]*x24 + N.cost[3,5]*x35 + N.cost[3,6]*x36 + N.cost[4,5]*x45 + N.cost[4,6]*x46;

# %% [markdown]
# We then have flow equilibrium constraints $x_{14} + x_{24} = x_{45} + x_{46}$,

# %%
flow_eq = x14 + x24 - (x45 + x46);

# %% [markdown]
# and a (nonconvex) defining equation for the blending variables $w_4=(x_{45} + x_{46}) = q_1x_{14} + q_2 x_{24}$ as the blended quality at the pool,

# %%
blend_eq = w4*(x45 + x46) - (N.q[1]*x14 + N.q[2]*x24);

# %% [markdown]
# quality bounds at the terminals $q_5(x_{45}+x_{36}) \geq (w_4 x_{45} + q_3 x_{35})$ and $q_6(x_{46}+x_{36}) \geq (w_4 x_{46} + q_3 x_{36})$

# %%
qual_bnd = [ N.q[5]*(x45+x36)-(w4*x45+N.q[3]*x35); N.q[6]*(x46+x36)-(w4*x46+N.q[3]*x36) ];

# %% [markdown]
# capacity bounds,

# %%
cap_bnd = [ N.cap[1]-x14; N.cap[2]-x24; N.cap[3]-(x35+x36); N.cap[4]-(x45+x46); N.cap[5]-(x35+x45); N.cap[6]-(x36+x46) ];

# %% [markdown]
# and finally nonnegativity of flow variables,

# %%
flow_bnd = [ x14; x24; x35; x36; x45; x46 ];

# %% [markdown]
# ## Solving the problem

# %% [markdown]
# We solve the second-order moment relaxation

# %%
prob = momentprob(2, obj, [qual_bnd; cap_bnd; flow_bnd], [flow_eq; blend_eq]);

# %%
X, Z, t, y, solsta = solve_mosek(prob);
# Out:
# Open file 'polyopt.task'
# Computer
#   Platform               : Linux/64-X86
#   Cores                  : 20
#
# Problem
#   Name                   :
#   Objective sense        : max
#   Type                   : CONIC (conic optimization problem)
#   Constraints            : 330
#   Cones                  : 0
#   Scalar variables       : 73
#   Matrix variables       : 15
#   Integer variables      : 0
#
# Optimizer started.
# Conic interior-point optimizer started.
# Presolve started.
# Linear dependency checker started.
# Linear dependency checker terminated.
# Eliminator started.
# Total number of eliminations : 0
# Eliminator terminated.
# Eliminator - tries                  : 1                 time                   : 0.00
# Eliminator - elim's                 : 0
# Lin. dep.  - tries                  : 1                 time                   : 0.00
# Lin. dep.  - number                 : 0
# Presolve terminated. Time: 0.00
# rnumcone: 0 0
# rnummcone: 1 numfrli: 74
# ======
# nrmc: 1.000000e+00 0.000000e+00
# flops: 1.197889e+07
# flops: 1.197889e+07
# flops: 1.197889e+07
# Factor flops: 1.20e+07 (0.00e+00)
# Optimizer  - threads                : 8
# Optimizer  - solved problem         : the primal
# Optimizer  - Constraints            : 330
# Optimizer  - Cones                  : 1
# Optimizer  - Scalar variables       : 74                conic                  : 74
# Optimizer  - Semi-definite variables: 15                scalarized             : 1170
# Factor     - setup time             : 0.01              dense det. time        : 0.00
# Factor     - ML order time          : 0.00              GP order time          : 0.00
# Factor     - nonzeros before factor : 5.46e+04          after factor           : 5.46e+04
# Factor     - dense dim.             : 0                 flops                  : 1.36e+07
# ITE PFEAS    DFEAS    GFEAS    PRSTATUS   POBJ              DOBJ              MU       TIME
# 0   6.0e+00  1.0e+00  1.0e+00  0.00e+00   0.000000000e+00   0.000000000e+00   1.0e+00  0.01
# 1   4.0e+00  6.7e-01  6.6e-01  -2.97e-01  -4.567060837e+00  -7.323747534e+00  6.7e-01  0.02
# 2   2.3e+00  3.8e-01  2.2e+00  1.40e+00   -7.861933135e+00  -3.579444348e+00  3.8e-01  0.03
# 3   9.0e-01  1.5e-01  1.4e+00  1.98e+00   -4.509289136e+00  -3.535864106e+00  1.5e-01  0.03
# 4   3.7e-01  6.2e-02  6.5e-01  1.43e+00   -1.196942885e+00  -8.854406382e-01  6.2e-02  0.04
# 5   1.0e-01  1.7e-02  3.2e-01  1.23e+00   -8.159419104e-01  -7.413082723e-01  1.7e-02  0.05
# 6   3.3e-02  5.5e-03  1.6e-01  9.21e-01   -9.298505856e-01  -9.067581378e-01  5.5e-03  0.06
# 7   1.0e-02  1.7e-03  8.7e-02  9.42e-01   -9.821427228e-01  -9.750587864e-01  1.7e-03  0.06
# 8   4.0e-03  6.6e-04  5.6e-02  1.06e+00   -9.912437807e-01  -9.885326048e-01  6.6e-04  0.07
# 9   1.4e-03  2.3e-04  3.1e-02  9.36e-01   -9.970981753e-01  -9.961620575e-01  2.3e-04  0.08
# 10  4.1e-04  6.8e-05  1.8e-02  1.11e+00   -9.987705237e-01  -9.984932603e-01  6.8e-05  0.09
# 11  8.3e-05  1.4e-05  7.7e-03  9.67e-01   -9.997706143e-01  -9.997176920e-01  1.4e-05  0.10
# 12  2.1e-05  3.5e-06  3.9e-03  9.83e-01   -9.999354335e-01  -9.999216769e-01  3.5e-06  0.11
# 13  6.8e-06  1.1e-06  2.3e-03  1.05e+00   -9.999771743e-01  -9.999726802e-01  1.1e-06  0.11
# 14  2.7e-06  4.5e-07  1.3e-03  8.92e-01   -9.999916015e-01  -9.999898326e-01  4.5e-07  0.12
# 15  7.9e-07  1.3e-07  8.1e-04  1.12e+00   -9.999969908e-01  -9.999964479e-01  1.3e-07  0.13
# 16  1.6e-07  2.7e-08  3.4e-04  9.65e-01   -9.999994111e-01  -9.999993066e-01  2.7e-08  0.14
# 17  4.8e-08  7.6e-09  1.7e-04  9.44e-01   -9.999998314e-01  -9.999998019e-01  7.6e-09  0.15
# 18  1.3e-08  2.2e-09  9.9e-05  9.25e-01   -9.999999543e-01  -9.999999451e-01  2.1e-09  0.15
# 19  8.8e-09  1.3e-09  6.1e-05  9.96e-01   -9.999999936e-01  -9.999999901e-01  7.9e-10  0.16
# 20  2.0e-09  4.8e-09  3.1e-05  1.00e+00   -9.999999933e-01  -9.999999923e-01  2.1e-10  0.17
# Interior-point optimizer terminated. Time: 0.17.
#
# Optimizer terminated. Time: 0.20
#
# Interior-point solution summary
#   Problem status  : PRIMAL_AND_DUAL_FEASIBLE
#   Solution status : OPTIMAL
#   Primal.  obj: -9.9999999325e-01   Viol.  con: 9e-09    var: 0e+00    barvar: 0e+00
#   Dual.    obj: -9.9999999235e-01   Viol.  con: 0e+00    var: 3e-10    barvar: 3e-10

# %% [markdown]
# We examine the solution,

# %%
[prob.basis[1:8] y[1:8]]
# Out:
# 8x2 Array{Polyopt.Poly{Float64},2}:
#  1.0  0.9999999999155574
#  x14  0.16666666805961045
#  x24  0.4999999895452832
#  x35  4.4077827315300884e-11
#  x36  1.4161301130673998e-9
#  x45  4.76887432148258e-9
#  x46  0.6666666531757295
#  w4   1.4999999440860132

# %% [markdown]
# and we we test feasibility,

# %%
[ Polyopt.evalpoly(h, y[2:8]) for h=[flow_eq; blend_eq] ]
# Out:
# 2-element Array{Any,1}:
#  -3.3971e-10
#  -4.40832e-8

# %%
[ Polyopt.evalpoly(g, y[2:8]) for g=[qual_bnd; cap_bnd; flow_bnd] ]
# Out:
# 14-element Array{Any,1}:
#  8.22104e-9
#  3.65679e-8
#  0.833333
#  0.5
#  1.0
#  0.333333
#  0.333333
#  1.20748e-8
#  0.166667
#  0.5
#  4.40778e-11
#  1.41613e-9
#  4.76887e-9
#  0.666667

# %% [markdown]
# since the extracted monomial solution is feasible, we have found the optimal solution.
